# %% [markdown]
# # Exercise: Mean & Median Customer Spend

# %% [markdown]
# Here's some code that will generate some random e-commerce data; just an array of total amount spent per transaction. Select the code block, and hit "play" to execute it:

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100, 20, 10000)
print(incomes)

plt.hist(incomes, 50)
plt.show()
# Out:
# [ 80.05595317  95.00060808 143.05058985 ... 103.37736499 107.4335564
#  115.68725852]

# %% [markdown]
# Now, find the mean and median of this data. In the code block below, write your code, and see if your result makes sense:

# %%
print(np.mean(incomes))
print(np.median(incomes))
# Out:
# 100.32306403881726
# 100.15260411467551

# %% [markdown]
# This is pretty much the world's easiest assignment, but we're just trying to get your hands on iPython and writing code with numpy to get you comfortable with it.
#
# Try playing with the code above to generate different distributions of data, or add outliers to it to see their effect.

# %%
#Appending an outlier value
incomes = np.append(incomes, [2000])
print(incomes)
plt.hist(incomes, 50)
plt.show()
# Out:
# [  80.05595317   95.00060808  143.05058985 ...  107.4335564   115.68725852
#  2000.        ]

# %%
# pop the last value. After that, the histogram regurned should have a normal distribution with a bell shape since the large outlier was removed
incomes = np.delete(incomes, len(incomes)-1)
print(incomes)
plt.hist(incomes, 50)
plt.show()
# Out:
# [ 80.05595317  95.00060808 143.05058985 ... 103.37736499 107.4335564
#  115.68725852]
