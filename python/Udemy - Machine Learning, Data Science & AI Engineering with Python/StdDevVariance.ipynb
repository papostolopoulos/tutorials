# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 20.0, 10000)
print(incomes)
plt.hist(incomes, 50)
plt.show()
# Out:
# [ 82.56011629  87.80476864  92.34012807 ... 107.46532687  94.72063106
#   90.07537492]

# %%
incomes.std()
# Out:
# np.float64(19.97429289249841)

# %%
incomes.var()
# Out:
# np.float64(398.9723765553126)

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?

# %%
ages = np.random.normal(80,20,10000)
plt.hist(ages, 50)
print("Standard Deviation:", ages.std())
print("Variance:", ages.var())
plt.show()
# Out:
# Standard Deviation: 20.05314494498091
# Variance: 402.1286221844135
