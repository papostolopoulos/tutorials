# %% [markdown]
# # Mean, Median, Mode, and introducing NumPy

# %% [markdown]
# ## Mean vs. Median

# %% [markdown]
# Let's create some fake income data, centered around 27,000 with a normal distribution and standard deviation of 15,000, with 10,000 data points. (We'll discuss those terms more later, if you're not familiar with them.)
#
# Then, compute the mean (average) - it should be close to 27,000:

# %%
import numpy as np
incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# np.float64(26743.368698445214)

# %% [markdown]
# We can segment the income data into 50 buckets, and plot it as a histogram:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# Now compute the median - since we have a nice, even distribution it too should be close to 27,000:

# %%
np.median(incomes)
# Out:
# np.float64(26868.243704719425)

# %% [markdown]
# Now we'll add Jeff Bezos into the mix. Darn income inequality!

# %%
incomes = np.append(incomes, [1000000000])
print(incomes)
# Out:
# [2.15075584e+03 6.75661080e+03 6.00232603e+03 ... 3.72817693e+04
#  2.18927062e+04 1.00000000e+09]

# %% [markdown]
# The median won't change much, but the mean does:

# %%
np.median(incomes)
# Out:
# np.float64(26596.75396899906)

# %%
np.mean(incomes)
# Out:
# np.float64(126730.69562888234)

# %% [markdown]
# ## Mode

# %% [markdown]
# Next, let's generate some fake age data for 500 people:

# %%
ages = np.random.randint(low=18, high=90, size=500)
ages
# Out:
# array([56, 31, 23, 86, 79, 44, 34, 55, 24, 43, 25, 35, 73, 88, 63, 37, 27,
#        45, 48, 85, 82, 84, 41, 32, 70, 41, 21, 54, 73, 28, 56, 47, 88, 22,
#        50, 37, 26, 35, 33, 39, 36, 43, 19, 58, 42, 59, 58, 49, 18, 50, 45,
#        28, 31, 21, 52, 34, 19, 47, 60, 70, 70, 29, 88, 30, 51, 76, 53, 43,
#        65, 87, 78, 38, 40, 31, 47, 76, 47, 31, 53, 57, 43, 36, 60, 50, 30,
#        32, 72, 27, 24, 35, 44, 46, 47, 76, 61, 88, 88, 68, 77, 30, 82, 23,
#        36, 86, 43, 69, 61, 88, 83, 84, 19, 50, 18, 27, 44, 19, 85, 43, 39,
#        52, 20, 41, 33, 75, 78, 49, 44, 86, 39, 48, 50, 87, 66, 18, 67, 27,
#        33, 50, 31, 35, 39, 82, 81, 28, 46, 34, 89, 88, 71, 82, 83, 66, 79,
#        24, 33, 35, 18, 86, 52, 64, 47, 20, 28, 82, 79, 42, 42, 40, 75, 81,
#        75, 44, 46, 87, 38, 38, 66, 24, 89, 40, 48, 82, 18, 27, 19, 63, 28,
#        22, 28, 38, 85, 46, 87, 26, 71, 33, 39, 85, 23, 38, 51, 42, 76, 82,
#        80, 84, 47, 33, 44, 81, 27, 21, 89, 71, 83, 35, 39, 36, 72, 40, 57,
#        18, 68, 81, 51, 19, 37, 45, 47, 83, 32, 66, 59, 42, 60, 18, 55, 47,
#        62, 64, 74, 18, 88, 88, 22, 43, 28, 20, 55, 31, 18, 57, 48, 40, 57,
#        22, 66, 89, 52, 74, 52, 88, 38, 63, 59, 52, 41, 30, 72, 67, 19, 29,
#        67, 35, 50, 26, 18, 54, 86, 39, 23, 50, 85, 87, 54, 23, 63, 59, 85,
#        33, 87, 36, 29, 20, 56, 72, 32, 32, 51, 76, 22, 47, 47, 32, 85, 70,
#        21, 49, 70, 22, 59, 18, 77, 62, 86, 89, 64, 22, 25, 73, 21, 24, 47,
#        20, 73, 60, 76, 52, 65, 73, 53, 78, 56, 74, 58, 40, 38, 58, 54, 31,
#        29, 24, 79, 62, 31, 89, 78, 35, 61, 69, 34, 41, 36, 86, 38, 33, 79,
#        79, 64, 18, 73, 80, 84, 54, 36, 77, 48, 79, 84, 44, 38, 77, 47, 68,
#        67, 52, 37, 31, 26, 20, 65, 26, 55, 27, 57, 48, 89, 61, 74, 83, 83,
#        51, 47, 28, 57, 64, 77, 83, 56, 85, 47, 60, 50, 57, 33, 61, 57, 28,
#        85, 43, 57, 57, 28, 63, 83, 41, 88, 29, 33, 87, 20, 59, 71, 34, 61,
#        87, 27, 40, 74, 20, 68, 39, 65, 51, 68, 62, 55, 86, 57, 41, 65, 29,
#        34, 58, 78, 55, 23, 58, 58, 19, 86, 49, 60, 30, 66, 83, 36, 40, 65,
#        79, 57, 27, 70, 77, 48, 18, 61, 61, 84, 31, 88, 24, 65, 48, 30, 38,
#        72, 29, 74, 38, 57, 74, 65, 41, 32, 34, 82, 66, 54, 86, 48, 89, 76,
#        39, 65, 19, 47, 18, 68, 52], dtype=int32)

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=np.int32(22), count=np.int64(12))
